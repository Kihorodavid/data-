# %%
import numpy as np

a =np.array(6)
b =np.array([2,6,8,5])
c= np.array([[2,4,6],[6,6,7]])
d= np.array([[[4,6,7],[4,6,8]],[[5,7,8],[6,7,8]]])

print("zero dimentional:" ,a)
print("1-D:" ,b)
print("2-D:" ,c)
print("3-D:" ,d)

print(a.ndim)
print(b.ndim)
print(c.ndim)
print(d.ndim)
# Out:
# zero dimentional: 6
# 1-D: [2 6 8 5]
# 2-D: [[2 4 6]
#  [6 6 7]]
# 3-D: [[[4 6 7]
#   [4 6 8]]
#
#  [[5 7 8]
#   [6 7 8]]]
# 0
# 1
# 2
# 3

# %%
from numpy import random
x = random.randint(100)
y = random.rand()
print(x)
print(y)
arr = random.randint(100, size=(4))
print(arr)
# Out:
# 81
# 0.1541669016745275
# [81 21 49 75]

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([0,1,2,3,4])
y = np.array([0,1,2,3,4])

plt.plot(x,y, marker = "*")
plt.title("Title")
plt.xlabel("x-axis")
plt.ylabel("y-axis")

plt.grid()
plt.show()

# %%
x_axis = np.array([0,3,5,7])
y_axis = np.array([0,5,10,16])

plt.scatter(x_axis,y_axis)
plt.show()

# %%
x= np.array(["Apples","Bananas","Mangoes","Grapes","avocado"])
y= np.array([4,15,3,23,10])

plt.bar(x,y, width=1 , color=("blue","green","red","black","yellow"))
plt.show()

# %%
x= np.array(["Apples","Bananas","Mangoes","Grapes","avocado"])
y= np.array([4,15,3,23,10])

plt.barh(x,y, height=0.75 , color=("blue","green","red","black","yellow"))
plt.show()

# %%
x= np.array([70,50,60,80])
my_label=["BMW","Jeep","Toyota","Volvo"]
my_colors= ["blue","green","red","black"]
my_explode=[0.3,0.05,0.05,0.015]

plt.pie(x,labels=my_label , colors=my_colors, explode=my_explode, shadow=True)
plt.legend(title="CARS")
plt.title("Cars")
plt.show()

# %%
from numpy import random
import matplotlib.pyplot as plt

x= random.randint(100,size =(5))
y= random.randint(100,size =(5))

print(x)
print(y)

plt.plot(x,y)
plt.show()
# Out:
# [99 56 17 81 82]
# [79 86  4 47 37]
